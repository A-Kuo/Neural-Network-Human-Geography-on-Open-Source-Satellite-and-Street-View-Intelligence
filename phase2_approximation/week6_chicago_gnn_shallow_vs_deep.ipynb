# %% [markdown]
# # Week 6: Chicago Real Data Experiments (Placeholder)
#
# Goal: Train GNNs on real Chicago data, compare shallow vs. deep.
#
# TODO (Week 6):
# - load_chicago_dataset() from data/processed/final_dataset.parquet
# - Build Chicago tract graph (spatial adjacency)
# - Train GNNs with depth 1, 2, 3, 4, 5, 6 (fixed hidden_dim)
# - Measure: test R² (income prediction)
# - Expected: Shallow plateau ~0.68, Deep reach ~0.82
# - Plot: test R² vs. depth
